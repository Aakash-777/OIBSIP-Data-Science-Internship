# %% [markdown]
# Importing Required Modules

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %% [markdown]
# Importing the processed-data

# %%
data = pd.read_csv('processed_data.csv')

# %%
data.head()
# Out:
#    car_ID  symboling                   CarName  fueltype  aspiration  \
# 0       1          3        alfa-romero giulia         0           0
# 1       2          3       alfa-romero stelvio         0           0
# 2       3          1  alfa-romero Quadrifoglio         0           0
# 3       4          2               audi 100 ls         0           0
# 4       5          2                audi 100ls         0           0
#
#    doornumber  carbody  drivewheel  enginelocation  wheelbase  ...  \
# 0           2        4           1               0       88.6  ...
# 1           2        4           1               0       88.6  ...
# 2           2        1           1               0       94.5  ...
# 3           4        0           0               0       99.8  ...
# 4           4        0           2               0       99.4  ...
#
#    enginesize  fuelsystem  boreratio  stroke  compressionratio horsepower  \
# 0         130           0       3.47    2.68               9.0        111
# 1         130           0       3.47    2.68               9.0        111
# 2         152           0       2.68    3.47               9.0        154
# 3         109           0       3.19    3.40              10.0        102
# 4         136           0       3.19    3.40               8.0        115
#
#    peakrpm  citympg  highwaympg    price
# 0     5000       21          27  13495.0
# 1     5000       21          27  16500.0
# 2     5000       19          26  16500.0
# 3     5500       24          30  13950.0
# 4     5500       18          22  17450.0
#
# [5 rows x 26 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    int64
#  4   aspiration        205 non-null    int64
#  5   doornumber        205 non-null    int64
#  6   carbody           205 non-null    int64
#  7   drivewheel        205 non-null    int64
#  8   enginelocation    205 non-null    int64
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    int64
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    int64
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(16), object(2)
# memory usage: 41.8+ KB

# %% [markdown]
# Dropping unnecessary data columns

# %%
c_data=data.drop(['car_ID','symboling','CarName','cylindernumber'],axis=1)

# %%
c_data = c_data[(c_data >= 0).all(axis=1)]

# %%
c_data.head()
# Out:
#    fueltype  aspiration  doornumber  carbody  drivewheel  enginelocation  \
# 0         0           0           2        4           1               0
# 1         0           0           2        4           1               0
# 2         0           0           2        1           1               0
# 3         0           0           4        0           0               0
# 4         0           0           4        0           2               0
#
#    wheelbase  carlength  carwidth  carheight  ...  enginesize  fuelsystem  \
# 0       88.6      168.8      64.1       48.8  ...         130           0
# 1       88.6      168.8      64.1       48.8  ...         130           0
# 2       94.5      171.2      65.5       52.4  ...         152           0
# 3       99.8      176.6      66.2       54.3  ...         109           0
# 4       99.4      176.6      66.4       54.3  ...         136           0
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0       3.47    2.68               9.0         111     5000       21
# 1       3.47    2.68               9.0         111     5000       21
# 2       2.68    3.47               9.0         154     5000       19
# 3       3.19    3.40              10.0         102     5500       24
# 4       3.19    3.40               8.0         115     5500       18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 22 columns]

# %%
print(c_data)
# Out:
#      fueltype  aspiration  doornumber  carbody  drivewheel  enginelocation  \
# 0           0           0           2        4           1               0
# 1           0           0           2        4           1               0
# 2           0           0           2        1           1               0
# 3           0           0           4        0           0               0
# 4           0           0           4        0           2               0
# ..        ...         ...         ...      ...         ...             ...
# 200         0           0           4        0           1               0
# 201         0           1           4        0           1               0
# 202         0           0           4        0           1               0
# 203         1           1           4        0           1               0
# 204         0           1           4        0           1               0
#
#      wheelbase  carlength  carwidth  carheight  ...  enginesize  fuelsystem  \
# 0         88.6      168.8      64.1       48.8  ...         130           0
# 1         88.6      168.8      64.1       48.8  ...         130           0
# 2         94.5      171.2      65.5       52.4  ...         152           0
# 3         99.8      176.6      66.2       54.3  ...         109           0
# 4         99.4      176.6      66.4       54.3  ...         136           0
# ..         ...        ...       ...        ...  ...         ...         ...
# 200      109.1      188.8      68.9       55.5  ...         141           0
# 201      109.1      188.8      68.8       55.5  ...         141           0
# 202      109.1      188.8      68.9       55.5  ...         173           0
# 203      109.1      188.8      68.9       55.5  ...         145           2
# 204      109.1      188.8      68.9       55.5  ...         141           0
#
#      boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0         3.47    2.68               9.0         111     5000       21
# 1         3.47    2.68               9.0         111     5000       21
# 2         2.68    3.47               9.0         154     5000       19
# 3         3.19    3.40              10.0         102     5500       24
# 4         3.19    3.40               8.0         115     5500       18
# ..         ...     ...               ...         ...      ...      ...
# 200       3.78    3.15               9.5         114     5400       23
# 201       3.78    3.15               8.7         160     5300       19
# 202       3.58    2.87               8.8         134     5500       18
# 203       3.01    3.40              23.0         106     4800       26
# 204       3.78    3.15               9.5         114     5400       19
#
#      highwaympg    price
# 0            27  13495.0
# 1            27  16500.0
# 2            26  16500.0
# 3            30  13950.0
# 4            22  17450.0
# ..          ...      ...
# 200          28  16845.0
# 201          25  19045.0
# 202          23  21485.0
# 203          27  22470.0
# 204          25  22625.0
#
# [205 rows x 22 columns]

# %% [markdown]
# Finding Correlation

# %%
c_data.corr()
# Out:
#                   fueltype  aspiration  doornumber   carbody  drivewheel  \
# fueltype          1.000000    0.401397    0.191491 -0.106275    0.051874
# aspiration        0.401397    1.000000    0.031792 -0.055455    0.153897
# doornumber        0.191491    0.031792    1.000000 -0.340507    0.004549
# carbody          -0.106275   -0.055455   -0.340507  1.000000    0.178462
# drivewheel        0.051874    0.153897    0.004549  0.178462    1.000000
# enginelocation   -0.040070   -0.057191   -0.137757  0.309907    0.113823
# wheelbase         0.308346    0.257611    0.447357 -0.170051    0.366828
# carlength         0.212679    0.234539    0.398568 -0.071322    0.416076
# carwidth          0.233880    0.300567    0.207168 -0.045453    0.376554
# carheight         0.284631    0.087311    0.552208 -0.078912    0.137255
# curbweight        0.217275    0.324902    0.197379  0.084982    0.573813
# enginetype        0.062651    0.061897   -0.033470  0.097284    0.388092
# enginesize        0.069594    0.108217    0.020742  0.104722    0.409914
# fuelsystem        0.254827    0.266364   -0.165059 -0.054393   -0.207202
# boreratio         0.054451    0.212614    0.119258  0.154351    0.512709
# stroke            0.241829    0.222982   -0.011082 -0.092747   -0.192827
# compressionratio  0.984356    0.295541    0.177888 -0.105144    0.018903
# horsepower       -0.163926    0.241685   -0.126947  0.129639    0.445806
# peakrpm          -0.476883   -0.183383   -0.247668  0.006010   -0.139905
# citympg           0.255963   -0.202362   -0.012417 -0.137525   -0.503655
# highwaympg        0.191392   -0.254416   -0.036330 -0.143814   -0.549492
# price             0.105679    0.177926    0.031835  0.107031    0.490739
#
#                   enginelocation  wheelbase  carlength  carwidth  carheight  \
# fueltype               -0.040070   0.308346   0.212679  0.233880   0.284631
# aspiration             -0.057191   0.257611   0.234539  0.300567   0.087311
# doornumber             -0.137757   0.447357   0.398568  0.207168   0.552208
# carbody                 0.309907  -0.170051  -0.071322 -0.045453  -0.078912
# drivewheel              0.113823   0.366828   0.416076  0.376554   0.137255
# enginelocation          1.000000  -0.187790  -0.050989 -0.051698  -0.106234
# wheelbase              -0.187790   1.000000   0.874587  0.795144   0.589435
# carlength              -0.050989   0.874587   1.000000  0.841118   0.491029
# carwidth               -0.051698   0.795144   0.841118  1.000000   0.279210
# carheight              -0.106234   0.589435   0.491029  0.279210   1.000000
# curbweight              0.050468   0.776386   0.877728  0.867032   0.295572
# enginetype              0.023221   0.289097   0.302642  0.328334  -0.013689
# enginesize              0.196826   0.569329   0.683360  0.735433   0.067149
# fuelsystem             -0.092625  -0.229733  -0.310001 -0.220772  -0.244916
# boreratio               0.185042   0.488750   0.606454  0.559150   0.171071
# stroke                 -0.138455   0.160959   0.129533  0.182942  -0.055307
# compressionratio       -0.019762   0.249786   0.158414  0.181129   0.261214
# horsepower              0.317839   0.353294   0.552623  0.640732  -0.108802
# peakrpm                 0.198461  -0.360469  -0.287242 -0.220012  -0.320411
# citympg                -0.153487  -0.470414  -0.670909 -0.642704  -0.048640
# highwaympg             -0.102026  -0.544082  -0.704662 -0.677218  -0.107358
# price                   0.324973   0.577816   0.682920  0.759325   0.119336
#
#                   ...  enginesize  fuelsystem  boreratio    stroke  \
# fueltype          ...    0.069594    0.254827   0.054451  0.241829
# aspiration        ...    0.108217    0.266364   0.212614  0.222982
# doornumber        ...    0.020742   -0.165059   0.119258 -0.011082
# carbody           ...    0.104722   -0.054393   0.154351 -0.092747
# drivewheel        ...    0.409914   -0.207202   0.512709 -0.192827
# enginelocation    ...    0.196826   -0.092625   0.185042 -0.138455
# wheelbase         ...    0.569329   -0.229733   0.488750  0.160959
# carlength         ...    0.683360   -0.310001   0.606454  0.129533
# carwidth          ...    0.735433   -0.220772   0.559150  0.182942
# carheight         ...    0.067149   -0.244916   0.171071 -0.055307
# curbweight        ...    0.850594   -0.229636   0.648480  0.168790
# enginetype        ...    0.245485   -0.061010   0.309614 -0.170408
# enginesize        ...    1.000000   -0.278248   0.583774  0.203129
# fuelsystem        ...   -0.278248    1.000000  -0.223946  0.301314
# boreratio         ...    0.583774   -0.223946   1.000000 -0.055909
# stroke            ...    0.203129    0.301314  -0.055909  1.000000
# compressionratio  ...    0.028971    0.223355   0.005197  0.186110
# horsepower        ...    0.809769   -0.271903   0.573677  0.080940
# peakrpm           ...   -0.244660    0.050362  -0.254976 -0.067964
# citympg           ...   -0.653658    0.246371  -0.584532 -0.042145
# highwaympg        ...   -0.677470    0.221552  -0.587012 -0.043931
# price             ...    0.874145   -0.275217   0.553173  0.079443
#
#                   compressionratio  horsepower   peakrpm   citympg  \
# fueltype                  0.984356   -0.163926 -0.476883  0.255963
# aspiration                0.295541    0.241685 -0.183383 -0.202362
# doornumber                0.177888   -0.126947 -0.247668 -0.012417
# carbody                  -0.105144    0.129639  0.006010 -0.137525
# drivewheel                0.018903    0.445806 -0.139905 -0.503655
# enginelocation           -0.019762    0.317839  0.198461 -0.153487
# wheelbase                 0.249786    0.353294 -0.360469 -0.470414
# carlength                 0.158414    0.552623 -0.287242 -0.670909
# carwidth                  0.181129    0.640732 -0.220012 -0.642704
# carheight                 0.261214   -0.108802 -0.320411 -0.048640
# curbweight                0.151362    0.750739 -0.266243 -0.757414
# enginetype                0.051809    0.366777  0.039353 -0.363421
# enginesize                0.028971    0.809769 -0.244660 -0.653658
# fuelsystem                0.223355   -0.271903  0.050362  0.246371
# boreratio                 0.005197    0.573677 -0.254976 -0.584532
# stroke                    0.186110    0.080940 -0.067964 -0.042145
# compressionratio          1.000000   -0.204326 -0.435741  0.324701
# horsepower               -0.204326    1.000000  0.131073 -0.801456
# peakrpm                  -0.435741    0.131073  1.000000 -0.113544
# citympg                   0.324701   -0.801456 -0.113544  1.000000
# highwaympg                0.265201   -0.770544 -0.054275  0.971337
# price                     0.067984    0.808139 -0.085267 -0.685751
#
#                   highwaympg     price
# fueltype            0.191392  0.105679
# aspiration         -0.254416  0.177926
# doornumber         -0.036330  0.031835
# carbody            -0.143814  0.107031
# drivewheel         -0.549492  0.490739
# enginelocation     -0.102026  0.324973
# wheelbase          -0.544082  0.577816
# carlength          -0.704662  0.682920
# carwidth           -0.677218  0.759325
# carheight          -0.107358  0.119336
# curbweight         -0.797465  0.835305
# enginetype         -0.380841  0.290890
# enginesize         -0.677470  0.874145
# fuelsystem          0.221552 -0.275217
# boreratio          -0.587012  0.553173
# stroke             -0.043931  0.079443
# compressionratio    0.265201  0.067984
# horsepower         -0.770544  0.808139
# peakrpm            -0.054275 -0.085267
# citympg             0.971337 -0.685751
# highwaympg          1.000000 -0.697599
# price              -0.697599  1.000000
#
# [22 rows x 22 columns]

# %% [markdown]
# Visualizing using seaborn

# %%
plt.figure(figsize=(30,20))
g=sns.heatmap(c_data.corr(),annot=True,cmap='viridis')
plt.show()

# %%
sns.pairplot(c_data)
# Out:
# C:\Users\Aakash\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Splitting data

# %%
x=c_data.drop(['price'],axis=1)
y=c_data['price']

# %%
print(x)

# %%
print(y)

# %% [markdown]
# Training Model

# %%
x_train,x_test,y_train,y_test=train_test_split(x, y ,test_size=0.3, random_state=101)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)

# %% [markdown]
# Prediction

# %%
y_pred_train=lr.predict(x_train)
y_pred_test=lr.predict(x_test)

# %%
print(y_pred_train,y_pred_test,sep="\n\n")

# %%
r2_train = r2_score(y_train,y_pred_train)
r2_test = r2_score(y_test,y_pred_test)
print("Accuracy(Train) : ",r2_train)
print("Accuracy(Test) : ",r2_test)

# %%
plt.scatter(y_test, y_pred_test)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title(" Actual Prices vs Predicted Prices")
plt.show()
